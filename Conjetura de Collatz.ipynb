# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#DEB887; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #4682B4">The Simplest Mathematical Problem No One Can Solve - Collatz Conjecture</p>

# %%
# !wget https://raw.githubusercontent.com/Ayrgthon/NoetherProyect/main/Blue-Gold%20Style -O CSS.css -q
    
from IPython.core.display import HTML
with open('./CSS.css', 'r') as file:
    custom_css = file.read()

HTML(custom_css)
# Out:
# <style>
# :root{
#     --header1_color: #204709;
#     --header2_color: #42841F;
#     --header3_color: #6EAF4B;
#     --keyword_color: #DEB887; /* import */
#     --string_color: #79740e;
#     --number_color: #8f3f71;
#     --def_color: #DEB887; /* class name */
#     --property_color: #d65d0e;
#     --builtin_color: #427b58;
#     --comment_color: #9f9f9f;
#     --comment_color_2: #828282;
#     --operator_color: #a221f2;
#     --font_color: #3c3836; /* general font */
#     --variable2_color: #b16286; /* self keyworda */
#     --box_color: #F0F8FF;
# }
#
# .cm-s-jupyter span.cm-def {
#     color: var(--def_color);
# }
# .cm-s-jupyter span.cm-operator{
#     color: var(--operator_color);
# }
#
# .cm-s-jupyter span.cm-keyword{
#     color: var(--keyword_color);
# }
#
# body[data-jp-theme-light="true"] .jp-Notebook .CodeMirror.cm-s-jupyter{
#     background-color: var(--box_color) !important;
# }
#
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #4682B4; font-size:100%; text-align:left; color: white;">
#
# <h3 align="left"><font color='#DEB887'>📌 Intro:</font></h3>
#
# The Collatz conjecture, also known as the 3n+1 problem or the Syracuse conjecture, is a famous mathematical conjecture formulated as follows:
#
# Given a positive integer n, if it is even, divide it by 2 (n/2), and if it is odd, multiply it by 3 and add 1 (3n+1). The process is repeated with the obtained result, generating a sequence of numbers. The conjecture states that regardless of the initial value of n, this sequence will eventually reach 1.
#
# Mathematically, we can express the process of the Collatz conjecture as follows:
#
# If n is even, n → n/2 If n is odd, n → 3n + 1
#
# This process is iteratively repeated until the value 1 is reached.
#
# The conjecture states that for any positive integer n, regardless of the chosen starting point, the resulting sequence will eventually reach the number 1 and remain in a repetitive cycle of the form (1, 4, 2, 1, 4, 2, ...).
#
# Although the Collatz conjecture has been proven for all integers up to approximately 2^60, its complete proof is still unknown. It remains an open problem in number theory and has intrigued mathematicians for decades.
#
# </div>

# %% [markdown]
#
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #4682B4; font-size:100%; text-align:left; color: white;">
#
# <h3 align="left"><font color='#DEB887'>📌 inspiration:</font></h3>
#
# I would like to give credit to the video "The Simplest Mathematical Problem No One Can Solve - Collatz Conjecture" by Veritasium for inspiring the creation of several graphs presented earlier. For your own good, if you are not familiar with Veritasium yet, I have done you the greatest favor of your lives jeje.
#
# </div>

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/094y1Z2wpJg" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>')
# Out:
# /opt/conda/lib/python3.10/site-packages/IPython/core/display.py:431: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/094y1Z2wpJg" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

newfigparams = {
                "figure.figsize": (10,4),
                "figure.dpi": 150,
                "axes.titlesize": 20,
                "axes.labelsize": 11,
                "ytick.labelsize": 11,
                "xtick.labelsize": 11,
                "legend.fontsize": 12,
                "legend.frameon": True,
                "lines.linewidth": 1,
                "axes.grid" : False
                }
plt.rcParams.update(newfigparams)
plt.style.use("ggplot")

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#DEB887; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #4682B4">First Look</p>

# %%
import matplotlib.pyplot as plt

def collatz(n):
    # Create a list to store the iterations
    iterations = [n]
    
    # Perform the iteration until n reaches 1
    while n != 1:
        # If n is even, divide by 2
        if n % 2 == 0:
            n = n // 2
        # If n is odd, multiply by 3 and add 1
        else:
            n = 3 * n + 1
        
        # Add the current number to the list of iterations
        iterations.append(n)
    
    # Return the list of iterations
    return iterations

# Create a list to store the lists of iterations
total_iterations = []

# Iterate over the numbers from 27 to 56 and save the iterations for each number
for i in range(5, 28):
    iterations = collatz(i)
    total_iterations.append(iterations)

# Sort the lists of iterations based on the length of iterations
sorted_iterations = sorted(total_iterations, key=lambda x: len(x), reverse=True)

# Select the top 5 lists with the highest number of iterations
top5_iterations = sorted_iterations[:5]

# Plot each of the lists of iterations in a separate figure
for i, iterations in enumerate(top5_iterations):
    plt.figure(i)
    plt.plot(iterations)
    plt.title(f'Number: {iterations[0]}, Iterations: {len(iterations)}', color='black')

plt.show()

# %%
data = []

for iteration in top5_iterations:
    row = {
        'Number': iteration[0],
        'Length': len(iteration),
        'Mean': sum(iteration)/len(iteration),
        'Max': max(iteration)
    }
    data.append(row)

df = pd.DataFrame(data)
display(df)
# Out:
#    Number  Length        Mean   Max
# 0      54     113  898.176991  9232
# 1      55     113  905.451327  9232
# 2      27     112  905.714286  9232
# 3      41     110  921.190909  9232
# 4      31     107  944.897196  9232

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#DEB887; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #4682B4">Logarithmic Scale and Stock Market</p>

# %%
# Create a list to store the lists of iterations
iteraciones_totales = []

# Iterate over numbers from 27 to 57 and save the iterations for each number
for i in range(27, 57):
    iteraciones = collatz(i)
    iteraciones_totales.append(iteraciones)

# Sort the lists of iterations in descending order of length and take the top 5
iteraciones_top5 = sorted(iteraciones_totales, key=len, reverse=True)[:5]

# Plot each of the iterations lists in a separate figure
for i, iteraciones in enumerate(iteraciones_top5):
    plt.figure(i)
    plt.plot(iteraciones)
    plt.title(f'Número: {iteraciones[0]}, Iteraciones: {len(iteraciones)}')
    plt.yscale('log')

plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #4682B4; font-size:100%; text-align:left; color: white;">
#
# <h3 align="left"><font color='#DEB887'>📌 Note:</font></h3>
#
# The resemblance between the logarithmic behavior of the Collatz conjecture and the logarithmic behavior of the stock market can be attributed to certain common characteristics in their random patterns and time scales.
#
# Both the Collatz conjecture and the stock market involve processes that are inherently random in nature. In the Collatz conjecture, the evolution of numbers through iterations is determined by specific mathematical rules, but the final outcome for each particular number is unpredictable and can appear random. Similarly, the stock market is influenced by a variety of unpredictable factors such as economic events, political decisions, and fluctuations in investor psychology, resulting in price movements that seem random.
#
# When graphically represented, both the Collatz conjecture and the stock market can exhibit complex and chaotic patterns on a linear scale. However, when a logarithmic scale is applied to the graphs, certain visual similarities can emerge.
#
# The logarithmic scale compresses values across a wide range into a more confined space, which highlights relative changes rather than absolute ones. This means that variations in smaller values become more visible, while variations in larger values are attenuated. Both the Collatz conjecture and stock prices in the market can exhibit more pronounced changes in the early stages or for smaller values, and then decrease in intensity as they approach larger or more stable values.
#
# In summary, the reason why logarithmic graphs of the Collatz conjecture and the stock market may appear similar is that both involve random processes and display complex patterns on a linear scale. By applying a logarithmic scale, relative variations are emphasized rather than absolute ones, which can reveal visual similarities between the two graphs. However, it is important to note that these similarities are purely visual and do not indicate a causal or direct relationship between the Collatz conjecture and the stock market.
#
# </div>

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#DEB887; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #4682B4">Graphs of Collatz Sequences</p>

# %%
import networkx as nx

# Create a list to store the lists of iterations
total_iterations = []

# Iterate over the numbers of interest and save the iterations for each number
numbers = [27, 31, 54, 55, 41]
for i in numbers:
    iterations = collatz(i)
    total_iterations.append(iterations)

# Create a directed graph for each list of iterations
for i, iterations in enumerate(total_iterations):
    plt.figure(figsize=(20, 20))
    G = nx.DiGraph()
    for j in range(len(iterations) - 1):
        G.add_edge(iterations[j], iterations[j+1])

    # Define the position of the nodes
    pos = nx.spring_layout(G)

    # Draw the nodes
    nx.draw_networkx_nodes(G, pos=pos, node_size=700, node_color='white', edgecolors='red')

    # Draw the node labels
    labels = {n: n for n in G.nodes()}
    nx.draw_networkx_labels(G, pos, labels, font_size=10, font_family='sans-serif')

    # Draw the edges with white arrows
    edges = G.edges()
    nx.draw_networkx_edges(G, pos=pos, node_size=2000, edgelist=edges, edge_color='blue', arrowsize=10, width=1)

    # Add the title with the number of iterations
    plt.title(f"Number: {numbers[i]}, Iterations: {len(iterations) - 1}", fontsize=12, fontweight='bold', color='black')

    # Show the graph
    plt.axis('off')
    plt.show()

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#DEB887; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #4682B4">Bentford's Law</p>

# %%
def calculate_digit_frequencies(number_list):
    frequencies = {i: 0 for i in range(1, 10)}
    for num in number_list:
        first_digit = int(str(num)[0])
        frequencies[first_digit] += 1
    total_numbers = len(number_list)
    for i in frequencies:
        frequencies[i] /= total_numbers
    return frequencies


initial_number = 10**6
iterations = collatz(initial_number)
digit_frequencies = calculate_digit_frequencies(iterations)

benford_law = {i: np.log10(1 + 1/i) for i in range(1, 10)}

fig, ax = plt.subplots()
ax.bar(benford_law.keys(), benford_law.values(), label='Benford\'s Law')
ax.bar(digit_frequencies.keys(), digit_frequencies.values(), label='Observed Frequency')
ax.set_xticks(list(range(1, 10)))
ax.legend()
plt.title(f"Digit Frequency in the Collatz Conjecture for n={initial_number}")
plt.xlabel('Digits')
plt.ylabel('Frequency')
plt.show()

# %%
# Generate a list of 100 starting numbers
origin_numbers = list(range(1, 101))

# Calculate the second largest number in each Collatz sequence corresponding to the starting numbers
secondary_numbers = []
for n in origin_numbers:
    sequence = list(collatz(n))
    sequence.sort(reverse=True)
    second_largest = None
    for num in sequence:
        if num < n:
            second_largest = num
            break
    secondary_numbers.append(second_largest)

# Plot the results
import matplotlib.pyplot as plt
plt.scatter(origin_numbers, secondary_numbers)
plt.title('Second Largest Number in Collatz Sequence')
plt.xlabel('Starting Number')
plt.ylabel('Second Largest Number')
plt.plot([1, 100], [1, 100], color = "blue")
plt.show()

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#DEB887; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #4682B4">Upper Bounds</p>

# %%
upper_bounds = []
for n in range(1, 1301):
    seq = collatz(n)
    upper_bounds.append(max(seq))
    
# Function for the Collatz conjecture
def collatz(n):
    count = 0
    while n != 1:
        if n % 2 == 0:
            n = n // 2
        else:
            n = 3 * n + 1
        count += 1
    return count

# Collatz values for numbers from 1 to 1300
collatz_values = [0] * 13000
for i in range(1, 13000):
    n = i
    while n != 1:
        if n % 2 == 0:
            n = n // 2
        else:
            n = 3 * n + 1
        collatz_values[i-1] += 1

# Upper bound
upper_bound = 9232

# Create scatter plot
plt.scatter(range(1, 13001), collatz_values, s=3)

# Draw horizontal line for the upper bound
plt.plot([0, 13000], [upper_bound, upper_bound], 'r--')

# Add labels and title
plt.xlabel('Number')
plt.ylabel('Collatz Conjecture Value')
plt.title('Upper Bound for Values between 1 and 1300')

plt.ylim(0, 300)
# Show the plot
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #4682B4; font-size:100%; text-align:left; color: white;">
#
# <h3 align="left"><font color='#DEB887'>📌 Conclusion:</font></h3>
#
# the generated graphs provide us with a deeper insight into the behavior of the Collatz conjecture. We observe patterns of convergence and variability in the number of iterations required for the first natural numbers to reach the value of 1. By applying a logarithmic scale, we can better appreciate the wide range of iteration counts, highlighting the similarities in logarithmic behavior across different initial numbers.
#
# The graphical representation of Collatz sequences as directed graphs allows us to visualize the progression of the sequence and observe patterns of branching and convergence towards 1. By examining the different graphs, we can identify recurring structures and appreciate the complexity of Collatz sequences.
#
# The analysis of digit frequency in the Collatz conjecture enables us to investigate whether the digit distribution in the sequence follows the expected patterns of Benford's Law. We compare the observed frequencies with the expected frequencies to determine if there are deviations or regularities in the digit distribution.
#
# Identifying the second-largest number in each Collatz sequence provides us with information about relative magnitudes and variations within the sequences. The presence of distinctive patterns or irregularities can be observed in the scatter plot.
#
# Furthermore, there is an interesting theory that suggests that if it could be proven that in every Collatz sequence there is at least one number smaller than the initial number in the sequence, then the entire conjecture could be proven. However, until now, such a proof has not been achieved.
#
# The theory is based on the idea that if at each step of the sequence a number smaller than the initial number is found, then the sequence would eventually reach 1. This can be illustrated with an example and an induction proof. For instance, let's consider the initial number 80. If we find a smaller number in the sequence, such as 40, and then this becomes the new initial number, and so on, this would refute the hypothesis that there are numbers that tend to infinity without stopping or the possibility of closed loops.
#
# It is important to note that this theory has not been proven yet, but many mathematicians consider it an interesting and valuable perspective in the study of the Collatz conjecture. The demonstration of this theory would have a significant impact on our understanding of the conjecture and its behavior in all possible sequences.
#
# Finally, by setting an upper bound for values between 1 and 1300, we can grasp the complexity and limits of the Collatz conjecture within this range of initial numbers.
#
# Collectively, these graphs provide us with valuable visualizations and help us better understand the mathematical properties and characteristics of the Collatz conjecture. They allow us to appreciate the complexity and beauty of this intriguing mathematical problem.
#
# </div>
